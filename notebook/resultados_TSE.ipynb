# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(
    'arquivo.txt', 
    sep=';',
    encoding='ISO-8859-1', 
    decimal=",",
    thousands=".",
    header=None,
    names=["DATA_GERACAO",'HORA_GERACAO','ANO_ELEICAO', 'NUM_TURNO','DESCRICAO_ELEICAO',
          'SIGLA_UF', 'SIGLA_UE', 'CODIGO_MUNICIPIO', 'NOME_MUNICIPIO', 'NUMERO_ZONA',
          'CODIGO_CARGO', 'NUMERO_CAND', 'SQ_CANDIDATO', 'NOME_CANDIDATO', 'NOME_URNA_CANDIDATO','DESCRICAO_CARGO',
          'COD_SIT_CAND_SUPERIOR', 'DESC_SIT_CAND_SUPERIOR', 'CODIGO_SIT_CANDIDATO', 'DESC_SIT_CANDIDATO', 
           'CODIGO_ELEITO', 'GANHOU', 'NUMERO_PARTIDO', 'SIGLA_PARTIDO', 'NOME_PARTIDO', 
           'SEQUENCIAL_LEGENDA', 'NOME_COLIGACAO', 'COMPOSICAO_LEGENDA', 'TOTAL_VOTOS'],
    index_col=False,
    dtype={'NOME_MUNICIPIO': str, 'NOME_PARTIDO': str}

    )

# %%
df.head(8)
# Out:
#   DATA_GERACAO HORA_GERACAO  ANO_ELEICAO  NUM_TURNO         DESCRICAO_ELEICAO  \
# 0   02/12/2016     19:39:15         2016          1  ELEIÇÕES MUNICIPAIS 2016
# 1   02/12/2016     19:39:15         2016          1  ELEIÇÕES MUNICIPAIS 2016
# 2   02/12/2016     19:39:15         2016          1  ELEIÇÕES MUNICIPAIS 2016
# 3   02/12/2016     19:39:15         2016          1  ELEIÇÕES MUNICIPAIS 2016
# 4   02/12/2016     19:39:15         2016          1  ELEIÇÕES MUNICIPAIS 2016
# 5   02/12/2016     19:39:15         2016          1  ELEIÇÕES MUNICIPAIS 2016
# 6   02/12/2016     19:39:15         2016          1  ELEIÇÕES MUNICIPAIS 2016
# 7   02/12/2016     19:39:15         2016          1  ELEIÇÕES MUNICIPAIS 2016
#
#   SIGLA_UF  SIGLA_UE  CODIGO_MUNICIPIO              NOME_MUNICIPIO  \
# 0       SP     61000             61000  EUCLIDES DA CUNHA PAULISTA
# 1       SP     61000             61000  EUCLIDES DA CUNHA PAULISTA
# ...

# %%
df.shape
# Out:
# (200866, 29)

# %%
df.columns
# Out:
# Index([u'DATA_GERACAO', u'HORA_GERACAO', u'ANO_ELEICAO', u'NUM_TURNO',
#        u'DESCRICAO_ELEICAO', u'SIGLA_UF', u'SIGLA_UE', u'CODIGO_MUNICIPIO',
#        u'NOME_MUNICIPIO', u'NUMERO_ZONA', u'CODIGO_CARGO', u'NUMERO_CAND',
#        u'SQ_CANDIDATO', u'NOME_CANDIDATO', u'NOME_URNA_CANDIDATO',
#        u'DESCRICAO_CARGO', u'COD_SIT_CAND_SUPERIOR', u'DESC_SIT_CAND_SUPERIOR',
#        u'CODIGO_SIT_CANDIDATO', u'DESC_SIT_CANDIDATO', u'CODIGO_ELEITO',
#        u'GANHOU', u'NUMERO_PARTIDO', u'SIGLA_PARTIDO', u'NOME_PARTIDO',
#        u'SEQUENCIAL_LEGENDA', u'NOME_COLIGACAO', u'COMPOSICAO_LEGENDA',
#        u'TOTAL_VOTOS'],
#       dtype='object')

# %%
df.dtypes
# Out:
# DATA_GERACAO               object
# HORA_GERACAO               object
# ANO_ELEICAO                 int64
# NUM_TURNO                   int64
# DESCRICAO_ELEICAO          object
# SIGLA_UF                   object
# SIGLA_UE                    int64
# CODIGO_MUNICIPIO            int64
# NOME_MUNICIPIO             object
# NUMERO_ZONA                 int64
# CODIGO_CARGO                int64
# NUMERO_CAND                 int64
# SQ_CANDIDATO                int64
# NOME_CANDIDATO             object
# NOME_URNA_CANDIDATO        object
# DESCRICAO_CARGO            object
# COD_SIT_CAND_SUPERIOR       int64
# DESC_SIT_CAND_SUPERIOR     object
# CODIGO_SIT_CANDIDATO        int64
# DESC_SIT_CANDIDATO         object
# CODIGO_ELEITO             float64
# GANHOU                     object
# NUMERO_PARTIDO              int64
# SIGLA_PARTIDO              object
# NOME_PARTIDO               object
# SEQUENCIAL_LEGENDA          int64
# NOME_COLIGACAO             object
# ...

# %%
sp = df[df['CODIGO_MUNICIPIO'] == 71072]

# %%
#(sp['ELEITO'] == 'ELEITO POR MÉDIA')
#(sp['ELEITO'] == 'ELEITO POR QP')

# %%
vereador = sp[(sp['DESCRICAO_CARGO'] == 'VEREADOR')]

# %%
vereador.shape
# Out:
# (73950, 29)

# %%
vereador1 = vereador.sort_values(by="TOTAL_VOTOS", ascending=False)

# %%
vereador1.head(50)
# Out:
#        DATA_GERACAO HORA_GERACAO  ANO_ELEICAO  NUM_TURNO  \
# 161364   02/12/2016     19:39:15         2016          1
# 163605   02/12/2016     19:39:15         2016          1
# 142430   02/12/2016     19:39:15         2016          1
# 159180   02/12/2016     19:39:15         2016          1
# 168112   02/12/2016     19:39:15         2016          1
# 144617   02/12/2016     19:39:15         2016          1
# 167794   02/12/2016     19:39:15         2016          1
# 137259   02/12/2016     19:39:15         2016          1
# 160434   02/12/2016     19:39:15         2016          1
# 127899   02/12/2016     19:39:15         2016          1
# 160078   02/12/2016     19:39:15         2016          1
# 168157   02/12/2016     19:39:15         2016          1
# 164306   02/12/2016     19:39:15         2016          1
# 134796   02/12/2016     19:39:15         2016          1
# 164898   02/12/2016     19:39:15         2016          1
# ...

# %%
vereador1.ix[161364]
# Out:
# DATA_GERACAO                            02/12/2016
# HORA_GERACAO                              19:39:15
# ANO_ELEICAO                                   2016
# NUM_TURNO                                        1
# DESCRICAO_ELEICAO         ELEIÇÕES MUNICIPAIS 2016
# SIGLA_UF                                        SP
# SIGLA_UE                                     71072
# CODIGO_MUNICIPIO                             71072
# NOME_MUNICIPIO                           SÃO PAULO
# NUMERO_ZONA                                    372
# CODIGO_CARGO                                    13
# NUMERO_CAND                                  25250
# SQ_CANDIDATO                          250000011022
# NOME_CANDIDATO               MILTON LEITE DA SILVA
# NOME_URNA_CANDIDATO                   MILTON LEITE
# DESCRICAO_CARGO                           VEREADOR
# COD_SIT_CAND_SUPERIOR                           12
# DESC_SIT_CAND_SUPERIOR                        APTO
# ...

# %%
vereador1['GANHOU'].drop_duplicates()
# Out:
# 161364       ELEITO POR QP
# 163605            SUPLENTE
# 168159    ELEITO POR MÉDIA
# 167597          NÃO ELEITO
# Name: GANHOU, dtype: object

# %%
vereador_qp = vereador[(vereador['GANHOU'] == u'ELEITO POR QP')]
vereador_media = vereador[(vereador['GANHOU'] == u'ELEITO POR MÉDIA')]

# %%
vereador_qp.shape
# Out:
# (2668, 29)

# %%
vereador_media.shape
# Out:
# (522, 29)

# %%
pd_eleitos = pd.concat([vereador_qp, vereador_media])

# %%
pd_eleitos.shape
# Out:
# (3190, 29)

# %%
pd_eleitos.sort_values(by="TOTAL_VOTOS", ascending=False)
# Out:
#        DATA_GERACAO HORA_GERACAO  ANO_ELEICAO  NUM_TURNO  \
# 161364   02/12/2016     19:39:15         2016          1
# 142430   02/12/2016     19:39:15         2016          1
# 159180   02/12/2016     19:39:15         2016          1
# 168112   02/12/2016     19:39:15         2016          1
# 144617   02/12/2016     19:39:15         2016          1
# 167794   02/12/2016     19:39:15         2016          1
# 137259   02/12/2016     19:39:15         2016          1
# 160434   02/12/2016     19:39:15         2016          1
# 127899   02/12/2016     19:39:15         2016          1
# 160078   02/12/2016     19:39:15         2016          1
# 168157   02/12/2016     19:39:15         2016          1
# 164306   02/12/2016     19:39:15         2016          1
# 164898   02/12/2016     19:39:15         2016          1
# 168159   02/12/2016     19:39:15         2016          1
# 142392   02/12/2016     19:39:15         2016          1
# ...

# %%
pd_eleitos[(pd_eleitos['NUMERO_CAND'] == 13131)]
# Out:
#        DATA_GERACAO HORA_GERACAO  ANO_ELEICAO  NUM_TURNO  \
# 114152   02/12/2016     19:39:15         2016          1
# 115438   02/12/2016     19:39:15         2016          1
# 116724   02/12/2016     19:39:15         2016          1
# 118010   02/12/2016     19:39:15         2016          1
# 119296   02/12/2016     19:39:15         2016          1
# 120582   02/12/2016     19:39:15         2016          1
# 121868   02/12/2016     19:39:15         2016          1
# 123154   02/12/2016     19:39:15         2016          1
# 124440   02/12/2016     19:39:15         2016          1
# 125726   02/12/2016     19:39:15         2016          1
# 127012   02/12/2016     19:39:15         2016          1
# 128298   02/12/2016     19:39:15         2016          1
# 129584   02/12/2016     19:39:15         2016          1
# 130870   02/12/2016     19:39:15         2016          1
# 132156   02/12/2016     19:39:15         2016          1
# ...

# %%
pd_eleitos.shape
# Out:
# (3190, 29)

# %%
eleitos = pd_eleitos.groupby('NOME_URNA_CANDIDATO')['TOTAL_VOTOS'].sum().reset_index()
eleitos.sort_values(by="TOTAL_VOTOS", ascending=False)
# Out:
#        NOME_URNA_CANDIDATO  TOTAL_VOTOS
# 19         EDUARDO SUPLICY       301446
# 34            MILTON LEITE       107957
# 53                 TRIPOLI        88843
# 13             CONTE LOPES        80052
# 33        MARIO COVAS NETO        75593
# 20            EDUARDO TUMA        70273
# 0           ADILSON AMADEU        67071
# 49            SOUZA SANTOS        55924
# 41           RICARDO NUNES        54692
# 10            CELSO JATENE        53715
# 21          ELISEU GABRIEL        52355
# 44         RODRIGO GOULART        49364
# 23        FERNANDO HOLIDAY        48055
# 7         ATILIO FRANCISCO        46961
# 36                     OTA        45915
# 47           SENIVAL MOURA        45320
# 37        PATRICIA BEZERRA        45285
# 31              JOÃO JORGE        42404
# 8           AURÉLIO NOMURA        41954
# 48                 SONINHA        40113
# 18              EDIR SALES        39062
# 27          GILSON BARRETO        38564
# ...

# %%
pd_eleitos.ix[161364]
# Out:
# DATA_GERACAO                            02/12/2016
# HORA_GERACAO                              19:39:15
# ANO_ELEICAO                                   2016
# NUM_TURNO                                        1
# DESCRICAO_ELEICAO         ELEIÇÕES MUNICIPAIS 2016
# SIGLA_UF                                        SP
# SIGLA_UE                                     71072
# CODIGO_MUNICIPIO                             71072
# NOME_MUNICIPIO                           SÃO PAULO
# NUMERO_ZONA                                    372
# CODIGO_CARGO                                    13
# NUMERO_CAND                                  25250
# SQ_CANDIDATO                          250000011022
# NOME_CANDIDATO               MILTON LEITE DA SILVA
# NOME_URNA_CANDIDATO                   MILTON LEITE
# DESCRICAO_CARGO                           VEREADOR
# COD_SIT_CAND_SUPERIOR                           12
# DESC_SIT_CAND_SUPERIOR                        APTO
# ...
